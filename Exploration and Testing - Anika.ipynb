# %%
import pandas as pd
from flask import Flask, jsonify, request, json

df = pd.read_csv('./JuxtaCityData2.csv')
df.head()
# Out:
#                          city         City Name     state  population  \
# 0          Newburgh, New York          Newburgh  New York       28363
# 1          Newstead, New York          Newstead  New York        8594
# 2     Niagara Falls, New York     Niagara Falls  New York       48460
# 3           Niagara, New York           Niagara  New York        8378
# 4  North Amityville, New York  North Amityville  New York       17862
#
#    population_change  Median_Age  Median_Income  per_capita_Income  \
# 0                0.4        27.8        38968.0            64894.0
# 1                2.3        43.8        58506.0            64894.0
# 2              -12.8        38.6        35995.0            64894.0
# 3               -6.7        43.4        53582.0            64894.0
# 4                7.8        34.1        73993.0            64894.0
#
#    Median_House_Value  Median Rent  ...  Property_taxes  Latitude  Longitude  \
# ...

# %%
df['id'] = df.index

# %%
df.head()
# Out:
#                          city         City Name     state  population  \
# 0          Newburgh, New York          Newburgh  New York       28363
# 1          Newstead, New York          Newstead  New York        8594
# 2     Niagara Falls, New York     Niagara Falls  New York       48460
# 3           Niagara, New York           Niagara  New York        8378
# 4  North Amityville, New York  North Amityville  New York       17862
#
#    population_change  Median_Age  Median_Income  per_capita_Income  \
# 0                0.4        27.8        38968.0            64894.0
# 1                2.3        43.8        58506.0            64894.0
# 2              -12.8        38.6        35995.0            64894.0
# 3               -6.7        43.4        53582.0            64894.0
# 4                7.8        34.1        73993.0            64894.0
#
#    Median_House_Value  Median Rent  ...  Latitude  Longitude  \
# 0            176678.0       1170.0  ...     41.50      74.02
# ...

# %%
df.to_csv('JuxtaCityData3.csv')

# %%
df = pd.read_csv('./JuxtaCityData3.csv')

# %%
id = 4489
city = df[df['id'] == id]
output = city.to_dict('records')
output[0]['city']
# Out:
# 'Birmingham, Alabama'

# %%
data = output[0]
pop = data['population']

# %%
population = f'The population is {pop} as of 2017,' 
# which is a {data['population_change']}% increase/decrease since 2000. The population density is {data['Population_Density']} people per square mile. Finally, the average resident age in {data['City Name']} is {data['Median_Age']} years old.'

population
# Out:
# 'The population is 210710 as of 2017,'

# %%
ids = []
input = 'Atl'
cities = df[df['city'].str.startswith(input)]
cities
# Out:
#       Unnamed: 0                       city      City Name       state  \
# 2444        2444  Atlantic City, New Jersey  Atlantic City  New Jersey
# 3229        3229           Atlanta, Georgia        Atlanta     Georgia
#
#       population  population_change  Median_Age  Median_Income  \
# 2444       38429               -5.2        36.8        37923.0
# 3229      486290               16.8        33.3        57597.0
#
#       per_capita_Income  Median_House_Value  ...  Latitude  Longitude  \
# 2444            80088.0            158655.0  ...     39.36      74.44
# 3229            56183.0            299400.0  ...     33.76      84.40
#
#       Average_Commute_Time    AQI  \
# 2444                  20.0  615.0
# 3229                  25.8  837.0
#
#                                                Nickname       HDTI  HDTIscore  \
# 2444                      \r\nA.C, America's Playground  42.327152 -14.327152
# ...

# %%
for index, row in cities.iterrows():
    ids.append(index)
    
ids
# Out:
# [2444, 3229]

# %%
length = len(ids)
length

for item in range(length):
    print(item)
# Out:
# 0
# 1
