# %%
import pandas as pd

df = pd.read_csv('./cleanedcitydata.csv')
df.head()
# Out:
#                          city         City_Name     state  population  \
# 0          Newburgh, New York          Newburgh  New York       28363
# 1          Newstead, New York          Newstead  New York        8594
# 2     Niagara Falls, New York     Niagara Falls  New York       48460
# 3           Niagara, New York           Niagara  New York        8378
# 4  North Amityville, New York  North Amityville  New York       17862
#
#    population_change  Median_Age  Median_Income  per_capita_Income  \
# 0                0.4        27.8        38968.0            64894.0
# 1                2.3        43.8        58506.0            64894.0
# 2              -12.8        38.6        35995.0            64894.0
# 3               -6.7        43.4        53582.0            64894.0
# 4                7.8        34.1        73993.0            64894.0
#
#    Median_House_Value  Median_Rent  Cost_of_Living_Index  \
# 0            176678.0       1170.0                 137.0
# ...

# %%
df.columns
# Out:
# Index(['city', 'City_Name', 'state', 'population', 'population_change',
#        'Median_Age', 'Median_Income', 'per_capita_Income',
#        'Median_House_Value', 'Median_Rent', 'Cost_of_Living_Index',
#        'Percent_below_Poverty', 'Population_Density', 'Unemployment_rate',
#        'Most_Common_Industries', 'Property_taxes', 'Latitude', 'Longitude',
#        'Average_Commute_Time', 'AQI'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# city                      0
# City_Name                 0
# state                     0
# population                0
# population_change         0
# Median_Age                0
# Median_Income             0
# per_capita_Income         0
# Median_House_Value        0
# Median_Rent               0
# Cost_of_Living_Index      0
# Percent_below_Poverty     0
# Population_Density        0
# Unemployment_rate         0
# Most_Common_Industries    0
# Property_taxes            0
# Latitude                  0
# Longitude                 0
# Average_Commute_Time      0
# AQI                       0
# dtype: int64
