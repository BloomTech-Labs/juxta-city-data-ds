# %%
import pandas as pd
import numpy as np
df = pd.read_csv('heartDisease_data_9001.csv')
df['Year'] = 2018
df
# Out:
#             City_Name     state  population  population_change  Median_Age  \
# 0       Niagara Falls  New York     48460.0              -12.8        38.6
# 1     North Tonawanda  New York     30475.0               -8.4        44.3
# 2               Nyack  New York      7040.0                4.5        42.1
# 3               Olean  New York     13711.0              -10.7        40.8
# 4             Oneonta  New York     14057.0                5.8        22.1
# ...               ...       ...         ...                ...         ...
# 1140           Tucson   Arizona    535677.0               10.1        34.1
# 1141       Wickenburg   Arizona      7409.0               45.8        60.5
# 1142        Youngtown   Arizona      6760.0              124.6        34.9
# 1143            Beebe  Arkansas      8146.0               65.2        35.1
# 1144      Blytheville  Arkansas     14051.0              -23.1        33.8
#
# ...

# %%
df.to_csv('heart_disease_data.csv')

# %%
lat_lon = pd.read_csv('lat_lon_counties.csv', sep=',')
lat_lon
# Out:
#       Unnamed: 0  Sort  State  FIPS      County  CountySeat(s)   \
# 0              0      1    AL   1001     Autauga     Prattville
# 1              1      2    AL   1003     Baldwin    Bay Minette
# 2              2      3    AL   1005     Barbour        Clayton
# 3              3      4    AL   1007        Bibb    Centreville
# 4              4      5    AL   1009      Blount        Oneonta
# ...          ...    ...   ...    ...         ...            ...
# 3138        3138   3139    WY  56037  Sweetwater    Green River
# 3139        3139   3140    WY  56039       Teton        Jackson
# 3140        3140   3141    WY  56041       Uinta       Evanston
# 3141        3141   3142    WY  56043    Washakie        Worland
# 3142        3142   3143    WY  56045      Weston      Newcastle
#
#      Population(2010) LandAreakm2  LandAreami2  WaterAreakm2  WaterAreami2   \
# 0              54,571    1,539.582      594.436        25.776         9.952
# ...

# %%
columns = ['State', 'FIPS', 'County', 'Hover']
lat_lon1 = lat_lon.reindex(columns = columns)
#lat_lon1 = lat_lon[['State', 'FIPS', 'County', 'Hover']]
#lat_lon1 = lat_lon.loc[:, ['State', 'FIPS', 'County', 'Hover']]
lat_lon1
# Out:
#      State  FIPS  County                      Hover
# 0       AL   NaN     NaN     Autauga<br>AL<br>01001
# 1       AL   NaN     NaN     Baldwin<br>AL<br>01003
# 2       AL   NaN     NaN     Barbour<br>AL<br>01005
# 3       AL   NaN     NaN        Bibb<br>AL<br>01007
# 4       AL   NaN     NaN      Blount<br>AL<br>01009
# ...    ...   ...     ...                        ...
# 3138    WY   NaN     NaN  Sweetwater<br>WY<br>56037
# 3139    WY   NaN     NaN       Teton<br>WY<br>56039
# 3140    WY   NaN     NaN       Uinta<br>WY<br>56041
# 3141    WY   NaN     NaN    Washakie<br>WY<br>56043
# 3142    WY   NaN     NaN      Weston<br>WY<br>56045
#
# [3143 rows x 4 columns]
