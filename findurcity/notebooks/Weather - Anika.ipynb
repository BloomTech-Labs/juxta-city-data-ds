# %%
# %load_ext pycodestyle_magic
# %pycodestyle_on

# %%
import pandas as pd

# %%
df = pd.read_csv('..\\src\\extraneous_datasets\\finaldataset.csv')
print(df.columns)
# Out:
# Index(['city', 'City_Name', 'state', 'population', 'population_change',
#        'Median_Age', 'Median_Income', 'per_capita_Income',
#        'Median_House_Value', 'Median_Rent', 'Cost_of_Living_Index',
#        'Percent_below_Poverty', 'Crime_rate', 'Population_Density',
#        'Unemployment_rate', 'Most_Common_Industries', 'Property_taxes',
#        'Latitude', 'Longitude', 'Average_Commute_Time', 'AQI', 'popden_score',
#        'popden_norm', 'HDTI', 'HDTIscore', 'HDTIscorenorm', 'RTI', 'RTIscore',
#        'RTIscorenorm', 'AQIscore', 'MedAgescore', 'Povertyscore', 'COLIscore',
#        'popchangescore', 'MedIncscore', 'PerCapIncscore', 'PopulationScore',
#        'EconomyScore', 'ClimateScore', 'CostofLivingScore', 'LivabilityScore',
#        'Coldday_Count', 'Hotday_Count', 'Rainday_Count'],
#       dtype='object')

# %%
final0318 = pd.read_csv('..\\src\\extraneous_datasets\\final_0318.csv')
print(final0318.columns)
# Out:
# Index(['Unnamed: 0', 'city', 'City_Name', 'state', 'population',
#        'population_change', 'Median_Age', 'Median_Income', 'per_capita_Income',
#        'Median_House_Value', 'Median_Rent', 'Cost_of_Living_Index',
#        'Percent_below_Poverty', 'Crime_rate', 'Population_Density',
#        'Unemployment_rate', 'Most_Common_Industries', 'Property_taxes',
#        'Latitude', 'Longitude', 'Average_Commute_Time', 'AQI', 'popden_score',
#        'popden_norm', 'HDTI', 'HDTIscore', 'HDTIscorenorm', 'RTI', 'RTIscore',
#        'RTIscorenorm', 'AQIscore', 'MedAgescore', 'Povertyscore', 'COLIscore',
#        'popchangescore', 'MedIncscore', 'PerCapIncscore', 'PopulationScore',
#        'EconomyScore', 'ClimateScore', 'CostofLivingScore', 'LivabilityScore',
#        'pop_rank', 'pop_ch_rank', 'med_age_rank', 'house_cost', 'rent_cost',
#        'pop_density', 'cli_index', 'avg_commute', 'air', 'id'],
#       dtype='object')

# %%
weather = df[['city', 'Coldday_Count', 'Hotday_Count', 'Rainday_Count']]
weather.head()
# Out:
#                   city  Coldday_Count  Hotday_Count  Rainday_Count
# 0    Addison, Illinois            180            14             91
# 1  Algonquin, Illinois            185            17             94
# 2      Alsip, Illinois            170            19             81
# 3      Alton, Illinois            127            15             76
# 4    Antioch, Illinois            195            10             78

# %%
final = final0318.merge(weather).drop(columns='Unnamed: 0')
final.columns
# Out:
# Index(['Unnamed: 0', 'city', 'City_Name', 'state', 'population',
#        'population_change', 'Median_Age', 'Median_Income', 'per_capita_Income',
#        'Median_House_Value', 'Median_Rent', 'Cost_of_Living_Index',
#        'Percent_below_Poverty', 'Crime_rate', 'Population_Density',
#        'Unemployment_rate', 'Most_Common_Industries', 'Property_taxes',
#        'Latitude', 'Longitude', 'Average_Commute_Time', 'AQI', 'popden_score',
#        'popden_norm', 'HDTI', 'HDTIscore', 'HDTIscorenorm', 'RTI', 'RTIscore',
#        'RTIscorenorm', 'AQIscore', 'MedAgescore', 'Povertyscore', 'COLIscore',
#        'popchangescore', 'MedIncscore', 'PerCapIncscore', 'PopulationScore',
#        'EconomyScore', 'ClimateScore', 'CostofLivingScore', 'LivabilityScore',
#        'pop_rank', 'pop_ch_rank', 'med_age_rank', 'house_cost', 'rent_cost',
#        'pop_density', 'cli_index', 'avg_commute', 'air', 'id', 'Coldday_Count',
#        'Hotday_Count', 'Rainday_Count'],
#       dtype='object')

# %%
final.head()
# Out:
#    Unnamed: 0                 city  City_Name     state  population  \
# 0           0    Addison, Illinois    Addison  Illinois       36820
# 1           1  Algonquin, Illinois  Algonquin  Illinois       31017
# 2           2      Alsip, Illinois      Alsip  Illinois       19079
# 3           3      Alton, Illinois      Alton  Illinois       26725
# 4           4    Antioch, Illinois    Antioch  Illinois       14235
#
#    population_change  Median_Age  Median_Income  per_capita_Income  \
# 0                2.5        35.8        62163.0            62992.0
# 1               33.3        40.3       108464.0            62992.0
# 2               -3.3        36.3        54178.0            62992.0
# 3              -12.4        37.9        38393.0            62992.0
# 4               62.0        38.0        83406.0            62992.0
#
#    Median_House_Value  ...  house_cost  rent_cost  pop_density cli_index  \
# 0            243610.0  ...           2          4            4         3
# ...

# %%
final.to_csv('..\\src\\extraneous_datasets\\final_0427.csv')
