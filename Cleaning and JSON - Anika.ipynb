# %%
import pandas as pd

df = pd.read_csv('./anika_cities-Copy1.csv')

df.head()
# Out:
#    Unnamed: 0                                               city population  \
# 0           0  https://www.city-data.com/city/Newburgh-New-Yo...     28,363
# 1           1  https://www.city-data.com/city/Newstead-New-Yo...     8,594.
# 2           2  https://www.city-data.com/city/Niagara-Falls-N...     48,460
# 3           3  https://www.city-data.com/city/Niagara-New-Yor...     8,378.
# 4           4  https://www.city-data.com/city/North-Amityvill...    17,862.
#
#   population_change  Median_Age Median_Income per_capita_Income  \
# 0             +0.4%        27.8       $38,968           $64,894
# 1             +2.3%        43.8       $58,506           $64,894
# 2            -12.8%        38.6       $35,995           $64,894
# 3             -6.7%        43.4       $53,582           $64,894
# 4             +7.8%        34.1       $73,993           $64,894
#
#   Median_House_Value Median Rent  Cost_of_Living_Index  ... Crime_rate  \
# ...

# %%
info = df[df['city'] == 'https://www.city-data.com/city/Newstead-New-York.html']
output = info.to_dict('index')
output[1]
# Out:
# {'Unnamed: 0': 1,
#  'city': 'https://www.city-data.com/city/Newstead-New-York.html',
#  'population': '8,594.',
#  'population_change': '+2.3%',
#  'Median_Age': 43.8,
#  'Median_Income': '$58,506',
#  'per_capita_Income': '$64,894',
#  'Median_House_Value': '$160,600',
#  'Median Rent': nan,
#  'Cost_of_Living_Index': 100.3,
#  'Percent_below_Poverty': nan,
#  'Crime_rate': nan,
#  'Population_Density': '169',
#  'Unemployment_rate': '4.3%',
#  'Most_Common_Industries': "['Educational services (10.9%)', 'Construction (7.8%)', 'Health care (7.6%)', 'Accommodation & food services (6.8%)', 'Food (5.3%)', 'Public administration (4.9%)', 'Food & beverage stores (3.4%)']",
#  'Property_taxes': '$2,287',
#  'Laitude': '43.01 N',
#  'Longitude': '78.52 W',
#  'Average_Commute_Time': '24.2 minutes',
#  'AQI': '62.4.',
#  'Nickname': nan}

# %%
info = df[df['city'].str.contains("New")]
output = info.to_dict('records')
info
# Out:
#       Unnamed: 0                                               city  \
# 0              0  https://www.city-data.com/city/Newburgh-New-Yo...
# 1              1  https://www.city-data.com/city/Newstead-New-Yo...
# 2              2  https://www.city-data.com/city/Niagara-Falls-N...
# 3              3  https://www.city-data.com/city/Niagara-New-Yor...
# 4              4  https://www.city-data.com/city/North-Amityvill...
# ...          ...                                                ...
# 1456        1456  https://www.city-data.com/city/New-Baltimore-V...
# 1457        1457  https://www.city-data.com/city/Newington-Fores...
# 1458        1458  https://www.city-data.com/city/Newington-Virgi...
# 1459        1459  https://www.city-data.com/city/Newport-News-Vi...
# 1640        1640  https://www.city-data.com/city/Newcastle-Washi...
#
#      population population_change  Median_Age Median_Income per_capita_Income  \
# ...

# %%
url = 'http://127.0.0.1:5000/data?city=https://www.city-data.com/city/Newburgh-New-York.html'

# %%
# # sample data
# data = {'https://www.city-data.com/city/Newburgh-New-York.html'}

# %%
def set_default(obj):
    if isinstance(obj, set):
        return list(obj)
    raise TypeError

# %%
import requests
import json

data = json.dumps(data, default = set_default)

# %%
send_request = requests.get(url)
print(send_request)

# %%
print(send_request.text)
